# %%
import pandas as pd

# %%
import streamlit as st
import numpy as np
import plotly.figure_factory as ff

# %%
sample_df = pd.read_csv('final_sample.csv')

# %%
sample_df
# Out:
#               Job Id     Experience Qualifications Salary Range  \
# 0   1909915087580037  0 to 11 Years             BA   $59K-$129K
# 1    170741571792910  5 to 12 Years             BA   $60K-$122K
# 2    234571556464181  1 to 15 Years            BCA    $65K-$99K
# 3    151561032441773  0 to 13 Years         M.Tech    $58K-$82K
# 4   1863790514095571  1 to 11 Years            PhD   $59K-$116K
# 5   1763048480282197  5 to 15 Years             BA    $63K-$89K
# 6    453992293716972  2 to 10 Years         M.Tech   $61K-$124K
# 7   2260878193766698  4 to 13 Years            MCA   $60K-$124K
# 8   2799255923142440  5 to 15 Years            MBA   $55K-$101K
# 9   1011225486447655  1 to 11 Years          M.Com    $60K-$95K
# 10   736523707712668  3 to 10 Years          M.Com   $62K-$104K
# 11  1508379277261083  2 to 10 Years             BA   $55K-$124K
# 12  1116175107001022  4 to 14 Years          M.Com   $65K-$122K
# 13  1961045010478106  0 to 15 Years         M.Tech   $65K-$129K
# ...

# %% [markdown]
# ### What is the distribution of Job Titles?

# %%
import plotly.graph_objects as go
fig = go.Figure(data=[go.Bar(x=sample_df.value_counts().index, y=sample_df.value_counts().values)])

# %%
st.plotly_chart(fig)
# Out:
# 2024-03-19 00:24:27.493
# ...
#   command:
#
#     streamlit run /Users/shreshtvenkatraman/opt/anaconda3/lib/python3.9/site-packages/ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator()
